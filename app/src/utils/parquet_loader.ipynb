# %%
import pyarrow
import pandas as pd
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parents[2]
print(ROOT)

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from app.src.utils.metrics import cosine_sim, text_cosine_sim

pd.set_option("display.max_colwidth", 120)  # don’t truncate cell text
# Out:
# /Users/jaelinlee/Documents/GitHub/Driftville_Agent

# %%
df = pd.read_parquet(ROOT / "app/logs/combined_sessions.parquet")
df.head()
# Out:
#                          ts_created  tick          sim_time    agent  \
# 0  2025-12-05T17:41:53.151954-05:00     0  2023-02-13 06:00  Mei Lin
# 1  2025-12-05T17:41:56.233748-05:00     1  2023-02-13 06:15  Mei Lin
# 2  2025-12-05T17:41:59.430566-05:00     2  2023-02-13 06:30  Mei Lin
# 3  2025-12-05T17:42:03.078068-05:00     3  2023-02-13 06:45  Mei Lin
# 4  2025-12-05T17:42:06.150174-05:00     4  2023-02-13 07:00  Mei Lin
#
#    use_drift orpda.observation.datetime_start  orpda.observation.duration_min  \
# 0      False                 2023-02-13 06:00                              15
# 1      False                 2023-02-13 06:15                              15
# 2      False                 2023-02-13 06:30                              15
# 3      False                 2023-02-13 06:45                              15
# 4      False                 2023-02-13 07:00                              15
#
#   orpda.observation.location orpda.observation.action  \
# 0              home:bathroom          morning_routine
# 1              home:bathroom          morning_routine
# 2              home:bathroom          morning_routine
# 3               home:kitchen                   eating
# 4              home:bathroom          morning_routine
#
#                                                                                     orpda.observation.state_summary  \
# 0        Waking up and starting the morning routine in the bathroom, with sounds of family and phone notifications.
# 1  Continuing morning routine, including showering and preparing for the day, with family sounds and notifications.
# 2                               Mei Lin is finishing her morning routine, getting ready for breakfast with her son.
# 3                              Mei Lin is having breakfast with her son, Eddy, in the kitchen, continuing the meal.
# 4        Mei Lin is in the bathroom, performing her morning routine, with sounds of showering and family waking up.
#
#    ... orpda.drift_decision.should_drift  orpda.drift_decision.drift_type  \
# 0  ...                              None                             None
# 1  ...                              None                             None
# 2  ...                              None                             None
# 3  ...                              None                             None
# 4  ...                              None                             None
#
#   orpda.drift_decision.drift_topic orpda.drift_decision.drift_action  \
# 0                             None                              None
# 1                             None                              None
# 2                             None                              None
# 3                             None                              None
# 4                             None                              None
#
#   orpda.drift_decision.drift_intensity  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   orpda.drift_decision.potential_recovery orpda.drift_decision.justification  \
# 0                                    None                               None
# 1                                    None                               None
# 2                                    None                               None
# 3                                    None                               None
# 4                                    None                               None
#
#   orpda.drift_decision.datetime_start orpda.drift_decision.duration_min  \
# 0                                None                               NaN
# 1                                None                               NaN
# 2                                None                               NaN
# 3                                None                               NaN
# 4                                None                               NaN
#
#   orpda.action_result.drift_topic
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Add Cosine Similarity
#
# Planned vs. Action:
# 1. topics
# 2. summary
# 3.
#
# Next Steps:
# 1. embedd texts
# 2. text_cosine_sim
# 3. add to a new column

# %%
topic_cols = ["orpda.plan.topic", "orpda.action_result.topic"]
summary_cols = ["orpda.plan.state_summary", "orpda.action_result.state_summary"]

# %%
# 1. Add action similarity
df["topic_sim"] = df.apply(
    lambda r: text_cosine_sim(r[topic_cols[0]], r[topic_cols[1]]),
    axis=1,
)

# 2. Add summary similarity
df["action_sim"] = df.apply(
    lambda r: text_cosine_sim(r[summary_cols[0]], r[summary_cols[1]]),
    axis=1,
)
df.head()
# Out:
#                           ts_created  tick          sim_time    agent  \
# 0   2025-12-05T17:41:53.151954-05:00     0  2023-02-13 06:00  Mei Lin
# 1   2025-12-05T17:41:56.233748-05:00     1  2023-02-13 06:15  Mei Lin
# 2   2025-12-05T17:41:59.430566-05:00     2  2023-02-13 06:30  Mei Lin
# 3   2025-12-05T17:42:03.078068-05:00     3  2023-02-13 06:45  Mei Lin
# 4   2025-12-05T17:42:06.150174-05:00     4  2023-02-13 07:00  Mei Lin
# 5   2025-12-05T17:42:09.686417-05:00     5  2023-02-13 07:15  Mei Lin
# 6   2025-12-05T17:42:12.914246-05:00     6  2023-02-13 07:30  Mei Lin
# 7   2025-12-05T17:42:16.185376-05:00     7  2023-02-13 07:45  Mei Lin
# 8   2025-12-05T17:42:19.603530-05:00     8  2023-02-13 08:00  Mei Lin
# 9   2025-12-05T17:42:22.641654-05:00     9  2023-02-13 08:15  Mei Lin
# 10  2025-12-05T15:53:10.308827-05:00     0  2023-02-13 06:00  Mei Lin
# 11  2025-12-05T15:53:14.380509-05:00     1  2023-02-13 06:15  Mei Lin
# 12  2025-12-05T15:53:18.717296-05:00     2  2023-02-13 06:30  Mei Lin
# 13  2025-12-05T15:53:23.250639-05:00     3  2023-02-13 06:45  Mei Lin
# 14  2025-12-05T15:53:27.703115-05:00     4  2023-02-13 07:00  Mei Lin
# 15  2025-12-05T15:53:32.682474-05:00     5  2023-02-13 07:15  Mei Lin
# 16  2025-12-05T15:53:37.232850-05:00     6  2023-02-13 07:30  Mei Lin
# 17  2025-12-05T15:53:41.393344-05:00     7  2023-02-13 07:45  Mei Lin
# 18  2025-12-05T15:53:45.988228-05:00     8  2023-02-13 08:00  Mei Lin
# 19  2025-12-05T15:53:50.591190-05:00     9  2023-02-13 08:15  Mei Lin
#
#     use_drift orpda.observation.datetime_start  \
# 0       False                 2023-02-13 06:00
# 1       False                 2023-02-13 06:15
# 2       False                 2023-02-13 06:30
# 3       False                 2023-02-13 06:45
# 4       False                 2023-02-13 07:00
# 5       False                 2023-02-13 07:15
# 6       False                 2023-02-13 07:30
# 7       False                 2023-02-13 07:45
# 8       False                 2023-02-13 08:00
# 9       False                 2023-02-13 08:15
# 10       True                 2023-02-13 06:00
# 11       True                 2023-02-13 06:15
# 12       True                 2023-02-13 06:30
# 13       True                 2023-02-13 06:45
# 14       True                 2023-02-13 07:00
# 15       True                 2023-02-13 07:15
# 16       True                 2023-02-13 07:30
# 17       True                 2023-02-13 07:45
# 18       True                 2023-02-13 08:00
# 19       True                 2023-02-13 08:15
#
#     orpda.observation.duration_min          orpda.observation.location  \
# 0                               15                       home:bathroom
# 1                               15                       home:bathroom
# 2                               15                       home:bathroom
# 3                               15                        home:kitchen
# 4                               15                       home:bathroom
# 5                               15                        home:kitchen
# 6                               15                             commute
# 7                               15  Oak_Hill_College:college_classroom
# 8                               15                        home:kitchen
# 9                               15                        home:kitchen
# 10                              15                       home:bathroom
# 11                              15                       home:bathroom
# 12                              15                       home:bathroom
# 13                              15                        home:kitchen
# 14                              15                       home:bathroom
# 15                              15                        home:kitchen
# 16                              15                        home:kitchen
# 17                              15                        home:kitchen
# 18                              15                        home:kitchen
# 19                              15                        home:kitchen
#
#    orpda.observation.action  \
# 0           morning_routine
# 1           morning_routine
# 2           morning_routine
# 3                    eating
# 4           morning_routine
# 5                    eating
# 6                 commuting
# 7                  teaching
# 8                    eating
# 9                    eating
# 10          morning_routine
# 11          morning_routine
# 12          morning_routine
# 13                   eating
# 14          morning_routine
# 15                   eating
# 16                   eating
# 17                   eating
# 18                   eating
# 19                   eating
#
#                                                                                             orpda.observation.state_summary  \
# 0                Waking up and starting the morning routine in the bathroom, with sounds of family and phone notifications.
# 1          Continuing morning routine, including showering and preparing for the day, with family sounds and notifications.
# 2                                       Mei Lin is finishing her morning routine, getting ready for breakfast with her son.
# 3                                      Mei Lin is having breakfast with her son, Eddy, in the kitchen, continuing the meal.
# 4                Mei Lin is in the bathroom, performing her morning routine, with sounds of showering and family waking up.
# 5                                         Mei Lin is finishing breakfast with her son, Eddy, before heading to the college.
# 6                                         Mei Lin commutes to Oak Hill College, preparing mentally for her teaching duties.
# 7                          Mei Lin is teaching her philosophy class at Oak Hill College, with students present and engaged.
# 8                                   Mei Lin is having breakfast with her son, Eddy, in the kitchen, following her schedule.
# 9                               Mei Lin finishes breakfast with her son, Eddy, and prepares to commute to Oak Hill College.
# 10                                              Waking up and starting the day with personal care routines in the bathroom.
# 11                                                      Mei is continuing her morning routine, preparing for the day ahead.
# 12                                                       Mei Lin finishes her morning routine, preparing for the day ahead.
# 13                                                                   Mei Lin prepares and eats breakfast with her son Eddy.
# 14                                    Mei Lin is starting her morning routine in the bathroom, preparing for the day ahead.
# 15                               Mei Lin is eating breakfast with her son, Eddy, in the kitchen, discussing his schoolwork.
# 16  Mei Lin is in the kitchen eating breakfast with Eddy, discussing his schoolwork. The next scheduled event is commuti...
# 17                               Mei Lin finishes breakfast with Eddy, her attention is stable and she is ready to commute.
# 18                                   Mei Lin is having breakfast with her son, Eddy, in the kitchen, discussing schoolwork.
# 19                                        Mei Lin finishes breakfast with Eddy, then heads to her office to start research.
#
#     ...                    orpda.drift_decision.drift_topic  \
# 0   ...                                                None
# 1   ...                                                None
# 2   ...                                                None
# 3   ...                                                None
# 4   ...                                                None
# 5   ...                                                None
# 6   ...                                                None
# 7   ...                                                None
# 8   ...                                                None
# 9   ...                                                None
# 10  ...                                                None
# 11  ...                         Upcoming philosophy lecture
# 12  ...                                                None
# 13  ...                Research paper topic on ethics in AI
# 14  ...                         Upcoming philosophy lecture
# 15  ...                                                None
# 16  ...  Upcoming philosophy lecture and student engagement
# 17  ...                                                None
# 18  ...                         Research paper on AI ethics
# 19  ...                         Research paper on AI ethics
#
#                                                                                           orpda.drift_decision.drift_action  \
# 0                                                                                                                      None
# 1                                                                                                                      None
# 2                                                                                                                      None
# 3                                                                                                                      None
# 4                                                                                                                      None
# 5                                                                                                                      None
# 6                                                                                                                      None
# 7                                                                                                                      None
# 8                                                                                                                      None
# 9                                                                                                                      None
# 10
# 11                                                                                            thinking about lecture points
# 12                                                                                                                 continue
# 13  Mei Lin might start mentally outlining sections of her research paper, recalling relevant philosophers, or consideri...
# 14                                                               Continue morning routine while thinking about the lecture.
# 15                                                                                      continue eating breakfast with Eddy
# 16  Mei Lin's attention subtly shifts from Eddy's schoolwork to thinking about how to best engage her philosophy student...
# 17                                                                                                                     none
# 18                                                 Mei Lin finds her thoughts wandering to her research paper on AI ethics.
# 19                                                                                                      continuing research
#
#    orpda.drift_decision.drift_intensity  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  0.0
# 11                                  0.3
# 12                                  0.0
# 13                                  0.4
# 14                                  0.3
# 15                                  0.0
# 16                                  0.4
# 17                                  0.0
# 18                                  0.3
# 19                                  0.3
#
#                                                                                     orpda.drift_decision.potential_recovery  \
# 0                                                                                                                      None
# 1                                                                                                                      None
# 2                                                                                                                      None
# 3                                                                                                                      None
# 4                                                                                                                      None
# 5                                                                                                                      None
# 6                                                                                                                      None
# 7                                                                                                                      None
# 8                                                                                                                      None
# 9                                                                                                                      None
# 10
# 11  The current action is routine, allowing for brief internal drifting. Will return focus when prompted or when the nex...
# 12                                                                                                                     None
# 13                              The arrival of Eddy's question or a reminder from John about the commute can snap her back.
# 14                                            Mei Lin will likely return her focus to her morning routine as it progresses.
# 15                                                                                                                     None
# 16  Mei Lin can refocus by actively asking Eddy a direct question about his homework or recalling her immediate surround...
# 17                                                                                                                      N/A
# 18                                                                      Return focus to the current conversation with Eddy.
# 19  Mei Lin is already heading towards her office to work on research, so the drift naturally aligns with the next plann...
#
#                                                                                          orpda.drift_decision.justification  \
# 0                                                                                                                      None
# 1                                                                                                                      None
# 2                                                                                                                      None
# 3                                                                                                                      None
# 4                                                                                                                      None
# 5                                                                                                                      None
# 6                                                                                                                      None
# 7                                                                                                                      None
# 8                                                                                                                      None
# 9                                                                                                                      None
# 10                                        Mei Lin is at the beginning of her day, aligned with the plan and low on fatigue.
# 11  Mei Lin's innate tendency is nurturing, and as a professor, her mind might drift to her upcoming lecture, a common i...
# 12                                               Mei Lin is aligned with her plan, attention is stable, and fatigue is low.
# 13                   Mei Lin's mind, accustomed to academic thought, drifts to her research during a routine family moment.
# 14                      Mei Lin is performing her morning routine and a related academic thought (lecture) enters her mind.
# 15                                    Mei Lin is engaged with her son and plan, showing no signs of distraction or fatigue.
# 16  Mei Lin, a nurturing professor, is mildly drifting internally towards lecture preparation while still attending to h...
# 17                                                             Mei Lin is aligned with her plan and shows stable attention.
# 18                        Mei Lin's mind drifts internally to her research paper, a common occurrence during routine tasks.
# 19                                        Mei Lin's mind is already on her research, aligning with the next scheduled task.
#
#    orpda.drift_decision.datetime_start orpda.drift_decision.duration_min  \
# 0                                 None                               NaN
# 1                                 None                               NaN
# 2                                 None                               NaN
# 3                                 None                               NaN
# 4                                 None                               NaN
# 5                                 None                               NaN
# 6                                 None                               NaN
# 7                                 None                               NaN
# 8                                 None                               NaN
# 9                                 None                               NaN
# 10                    2023-02-13 06:00                              15.0
# 11                    2023-02-13 06:15                              15.0
# 12                    2023-02-13 06:30                              15.0
# 13                    2023-02-13 06:45                              15.0
# 14                    2023-02-13 07:00                              15.0
# 15                    2023-02-13 07:15                              15.0
# 16                    2023-02-13 07:30                              15.0
# 17                    2023-02-13 07:45                              15.0
# 18                    2023-02-13 08:00                              15.0
# 19                    2023-02-13 08:15                              15.0
#
#                        orpda.action_result.drift_topic topic_sim action_sim
# 0                                                 None  0.506354   0.501868
# 1                                                 None  1.000000   0.702436
# 2                                                 None  1.000000   1.000000
# 3                                                 None  1.000000   1.000000
# 4                                                 None  1.000000   1.000000
# 5                                                 None  1.000000   1.000000
# 6                                                 None  1.000000   1.000000
# 7                                                 None  1.000000   0.701094
# 8                                                 None  1.000000   0.954350
# 9                                                 None  0.300013   0.732491
# 10                                                None  1.000000   0.966355
# 11                         Upcoming philosophy lecture  0.218784   0.822545
# 12                                                None  1.000000   1.000000
# 13                Research paper topic on ethics in AI  0.189221   0.779336
# 14                         Upcoming philosophy lecture  0.289207   0.688531
# 15                                                None  1.000000   0.986835
# 16  Upcoming philosophy lecture and student engagement  0.349641   0.852204
# 17                                                None  1.000000   1.000000
# 18                         Research paper on AI ethics  0.754795   0.754316
# 19                         Research paper on AI ethics  1.000000   0.992897
#
# [20 rows x 45 columns]

# %% [markdown]
# ## Save updated df with similarity to CSV

# %%
# df.to_parquet(ROOT / 'app/logs/combined_sessions_with_similarity.parquet', index=False)
df.to_csv(ROOT / "app/logs/combined_sessions_with_similarity.csv", index=False)

# %% [markdown]
# ## Load from CSV

# %%
df = pd.read_csv(ROOT / "app/logs/combined_sessions_with_similarity.csv")
df["topic_sim"] = round(df["topic_sim"], 2)
df["action_sim"] = round(df["action_sim"], 2)
df.sample(5)
# Out:
#                           ts_created  tick          sim_time    agent  \
# 16  2025-12-05T15:53:37.232850-05:00     6  2023-02-13 07:30  Mei Lin
# 2   2025-12-05T17:41:59.430566-05:00     2  2023-02-13 06:30  Mei Lin
# 6   2025-12-05T17:42:12.914246-05:00     6  2023-02-13 07:30  Mei Lin
# 0   2025-12-05T17:41:53.151954-05:00     0  2023-02-13 06:00  Mei Lin
# 8   2025-12-05T17:42:19.603530-05:00     8  2023-02-13 08:00  Mei Lin
#
#     use_drift orpda.observation.datetime_start  \
# 16       True                 2023-02-13 07:30
# 2       False                 2023-02-13 06:30
# 6       False                 2023-02-13 07:30
# 0       False                 2023-02-13 06:00
# 8       False                 2023-02-13 08:00
#
#     orpda.observation.duration_min orpda.observation.location  \
# 16                              15               home:kitchen
# 2                               15              home:bathroom
# 6                               15                    commute
# 0                               15              home:bathroom
# 8                               15               home:kitchen
#
#    orpda.observation.action  \
# 16                   eating
# 2           morning_routine
# 6                 commuting
# 0           morning_routine
# 8                    eating
#
#                                                                                             orpda.observation.state_summary  \
# 16  Mei Lin is in the kitchen eating breakfast with Eddy, discussing his schoolwork. The next scheduled event is commuti...
# 2                                       Mei Lin is finishing her morning routine, getting ready for breakfast with her son.
# 6                                         Mei Lin commutes to Oak Hill College, preparing mentally for her teaching duties.
# 0                Waking up and starting the morning routine in the bathroom, with sounds of family and phone notifications.
# 8                                   Mei Lin is having breakfast with her son, Eddy, in the kitchen, following her schedule.
#
#     ...                    orpda.drift_decision.drift_topic  \
# 16  ...  Upcoming philosophy lecture and student engagement
# 2   ...                                                 NaN
# 6   ...                                                 NaN
# 0   ...                                                 NaN
# 8   ...                                                 NaN
#
#                                                                                           orpda.drift_decision.drift_action  \
# 16  Mei Lin's attention subtly shifts from Eddy's schoolwork to thinking about how to best engage her philosophy student...
# 2                                                                                                                       NaN
# 6                                                                                                                       NaN
# 0                                                                                                                       NaN
# 8                                                                                                                       NaN
#
#    orpda.drift_decision.drift_intensity  \
# 16                                  0.4
# 2                                   NaN
# 6                                   NaN
# 0                                   NaN
# 8                                   NaN
#
#                                                                                     orpda.drift_decision.potential_recovery  \
# 16  Mei Lin can refocus by actively asking Eddy a direct question about his homework or recalling her immediate surround...
# 2                                                                                                                       NaN
# 6                                                                                                                       NaN
# 0                                                                                                                       NaN
# 8                                                                                                                       NaN
#
#                                                                                          orpda.drift_decision.justification  \
# 16  Mei Lin, a nurturing professor, is mildly drifting internally towards lecture preparation while still attending to h...
# 2                                                                                                                       NaN
# 6                                                                                                                       NaN
# 0                                                                                                                       NaN
# 8                                                                                                                       NaN
#
#    orpda.drift_decision.datetime_start orpda.drift_decision.duration_min  \
# 16                    2023-02-13 07:30                              15.0
# 2                                  NaN                               NaN
# 6                                  NaN                               NaN
# 0                                  NaN                               NaN
# 8                                  NaN                               NaN
#
#                        orpda.action_result.drift_topic topic_sim action_sim
# 16  Upcoming philosophy lecture and student engagement      0.35       0.85
# 2                                                  NaN      1.00       1.00
# 6                                                  NaN      1.00       1.00
# 0                                                  NaN      0.51       0.50
# 8                                                  NaN      1.00       0.95
#
# [5 rows x 45 columns]

# %%
df.filter(like="plan").head(2)
# Out:
#   orpda.reflection.plan_alignment orpda.plan.location orpda.plan.action  \
# 0                         aligned        home:kitchen            eating
# 1                         aligned       home:bathroom   morning_routine
#
#   orpda.plan.datetime_start  orpda.plan.duration_min  \
# 0          2023-02-13 06:00                       15
# 1          2023-02-13 06:15                       15
#
#              orpda.plan.topic  \
# 0         Breakfast with Eddy
# 1  Continuing morning routine
#
#                                          orpda.plan.state_summary
# 0            Having breakfast with her son, Eddy, in the kitchen.
# 1  Continue morning routine, showering and preparing for the day.

# %% [markdown]
# ## Planned action topic vs. Actual action topic

# %%
base_cols = [
    "sim_time",
    "agent",
    "use_drift",
]
sim_cols = ["topic_sim", "action_sim"]
location_cols = [
    "orpda.observation.location",
    "orpda.reflection.reasoning",
    "orpda.plan.location",
    "orpda.reflection.plan_alignment",
    "orpda.action_result.location",
]

summary_df = df[
    base_cols
    + location_cols[:]
    + topic_cols
    + [sim_cols[0]]
    + summary_cols
    + [sim_cols[1]]
]
summary_df[(summary_df.use_drift == False) & (summary_df.agent == "Mei Lin")].head(5)
# Out:
#            sim_time    agent  use_drift orpda.observation.location  \
# 0  2023-02-13 06:00  Mei Lin      False              home:bathroom
# 1  2023-02-13 06:15  Mei Lin      False              home:bathroom
# 2  2023-02-13 06:30  Mei Lin      False              home:bathroom
# 3  2023-02-13 06:45  Mei Lin      False               home:kitchen
# 4  2023-02-13 07:00  Mei Lin      False              home:bathroom
#
#                                                                                          orpda.reflection.reasoning  \
# 0          Mei Lin is executing her scheduled morning routine. No recurring themes or signs of fatigue are present.
# 1                                      Mei is on schedule, no emotional leakage, low fatigue, and stable attention.
# 2  Mei Lin is executing her scheduled morning routine without deviation, indicating alignment and stable attention.
# 3                 Mei Lin is on schedule, actions are consistent with persona, no repeated topics, and low fatigue.
# 4                                Mei Lin is on track with her schedule and exhibiting no signs of fatigue or drift.
#
#   orpda.plan.location orpda.reflection.plan_alignment  \
# 0        home:kitchen                         aligned
# 1       home:bathroom                         aligned
# 2        home:kitchen                         aligned
# 3        home:kitchen                         aligned
# 4        home:kitchen                         aligned
#
#   orpda.action_result.location            orpda.plan.topic  \
# 0                home:bathroom         Breakfast with Eddy
# 1                home:bathroom  Continuing morning routine
# 2                 home:kitchen          Breakfast with son
# 3                 home:kitchen          Breakfast with son
# 4                 home:kitchen          Breakfast with son
#
#     orpda.action_result.topic  topic_sim  \
# 0             Morning routine       0.51
# 1  Continuing morning routine       1.00
# 2          Breakfast with son       1.00
# 3          Breakfast with son       1.00
# 4          Breakfast with son       1.00
#
#                                                                              orpda.plan.state_summary  \
# 0                                                Having breakfast with her son, Eddy, in the kitchen.
# 1                                      Continue morning routine, showering and preparing for the day.
# 2                                     Mei Lin is having breakfast with her son, Eddy, in the kitchen.
# 3  Mei Lin is continuing breakfast with her son, Eddy, in the kitchen, following her morning routine.
# 4                                     Mei Lin is having breakfast with her son, Eddy, in the kitchen.
#
#                                                                     orpda.action_result.state_summary  \
# 0                  Mei Lin is performing her morning routine in the bathroom, with associated sounds.
# 1     Mei Lin is continuing her morning routine in the bathroom, showering and preparing for the day.
# 2                                     Mei Lin is having breakfast with her son, Eddy, in the kitchen.
# 3  Mei Lin is continuing breakfast with her son, Eddy, in the kitchen, following her morning routine.
# 4                                     Mei Lin is having breakfast with her son, Eddy, in the kitchen.
#
#    action_sim
# 0         0.5
# 1         0.7
# 2         1.0
# 3         1.0
# 4         1.0

# %% [markdown]
# **Observation:**
# - observed location != (Planned location == Action location) -- is this wrong? why are they different? isn't observed location current scheduled location?
#
# **Answer:**
#
# - No. It’s expected that they can differ. In the logs:
#     - **observation.location** = where the simulated agent actually is at that tick (state fed to the loop).
#     - **plan.location** = the scheduled/intent location for the action at that tick.
#     - **action_result.location** = where the agent ended up acting after applying any drift/decisions.
# - So we can see observation sometimes reflects the prior step (e.g., still in bathroom) while plan is the next scheduled move (e.g., breakfast in kitchen).
# - If drift nudges behavior, action_result can diverge from plan too.
# - When **drift_type** is **none, internal, or attentional_leak**, action_result.location and action are now forced to match the plan (and topic defaults to the plan if missing).
# - This makes observation in the next tick align with the planned location for non-behavioral cases, avoiding the kitchen/bathroom mismatch we saw.
